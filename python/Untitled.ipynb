# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("asset_prices.csv")
filled_orders = pd.read_csv("filled_orders.csv")

# %%
df.close.plot()
# Out:
# <AxesSubplot:>
